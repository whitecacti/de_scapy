# %%
import scapy.all as scapy
from scapy.all import sr, IP, conf, srp, Ether, ARP, arping
from scapy.layers.dot11 import RadioTap, Dot11, Dot11Deauth
from threading import Thread
import pandas
import time
import os

# Extcap interfaces - https://www.wireshark.org/docs/man-pages/extcap.html
# Wireshark stuff
# load_extcap()

# print all interfaces
print(conf.ifaces)

# get ip and mac of interface
print(scapy.get_if_addr("eth0"))
print(scapy.get_if_hwaddr("eth0"))

# %%
import descapy as des

# %%
interace = des.InterfaceDE()

# %%
interace.scan(scan_time=5)

# %%
interace.networks_list.__len__()
